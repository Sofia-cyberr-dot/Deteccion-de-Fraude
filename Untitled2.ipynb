# %% [markdown]
# <a href="https://colab.research.google.com/github/Sofia-cyberr-dot/Deteccion-de-Fraude/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***Importamoos Librerias***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/fraude_dataset.csv")

df.head()

# %% [markdown]
# ### Analisis ***Inicial***

# %%
df.info()

df.describe()

# %% [markdown]
# ### Preparar los ***datos***

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

df_copy = df.copy()

le = LabelEncoder()
df_copy["tipo_transaccion"] = le.fit_transform(df_copy["tipo_transaccion"])
df_copy["pais"] = le.fit_transform(df_copy["pais"])
df_copy["dispositivo"] = le.fit_transform(df_copy["dispositivo"])
df_copy["hora"] = le.fit_transform(df_copy["hora"])

X = df_copy.drop("fraude", axis=1)
y = df_copy["fraude"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Entrenar un modelo simple (Random Forest)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, y_train)

# %% [markdown]
# # Métricas del modelo***

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))

# %% [markdown]
# ### *Matriz de confusión (gráfico)*

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Matriz de Confusión")
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.show()
